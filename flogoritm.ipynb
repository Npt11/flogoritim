# %% [markdown]
# ![prodotti%20liste%20quadrati%20-%20Flowgorithm%2014_11_2023%2009_13_59.png](attachment:prodotti%20liste%20quadrati%20-%20Flowgorithm%2014_11_2023%2009_13_59.png)

# %%
l1 = [0] * (3)
l2 = [0] * (3)
q = [0] * (3)
q2 = [0] * (3)

print("dammi lista 1")
for i in range(0, 2 + 1, 1):
    l1[i] = int(input())
print("dammi lista 2")
for i in range(0, 2 + 1, 1):
    l2[i] = int(input())
print("calcolo i quadrati")
for i in range(0, 2 + 1, 1):
    q[i] = l1[i] ** 2
    print(q[i])
for i in range(0, 2 + 1, 1):
    q2[i] = l2[i] ** 2
    print(q2[i])
print("calcolo i prodotti")
for i in range(0, 2 + 1, 1):
    prodotto = q[i] * q2[i]
    print(prodotto)
# Out:
# dammi lista 1
# 3
# 4
# 5
# dammi lista 2
# 2
# 6
# 7
# calcolo i quadrati
# 9
# 16
# 25
# 4
# 36
# 49
# calcolo i prodotti
# 36
# 576
# 1225

# %% [markdown]
# ![prodotti%20liste%20quadrati%20-%20Flowgorithm%2014_11_2023%2009_18_19.png](attachment:prodotti%20liste%20quadrati%20-%20Flowgorithm%2014_11_2023%2009_18_19.png)

# %%
print("dammi i numeri")
n1 = float(input())
n2 = float(input())
if n1 == n2:
    print(" i numeri sono uguali")
else:
    print(" i numeri sono diversi")
# Out:
# dammi i numeri
# 2
# 2
#  i numeri sono uguali

# %% [markdown]
# ![numeri%20uguali%20-%20Flowgorithm%2014_11_2023%2009_22_05.png](attachment:numeri%20uguali%20-%20Flowgorithm%2014_11_2023%2009_22_05.png)

# %%
print("cosa vuoi fare?")
scelta = input()
print("dammi il primo numero")
n1 = float(input())
print("dammi il secondo numero")
n2 = float(input())
if scelta == "addizione":
    risultato = n1 + n2
else:
    if scelta == "sottrazione":
        risultato = n1 - n2
    else:
        if scelta == "divisione":
            risultato = n1 / n2
        else:
            if scelta == "moltiplicazione":
                risultato = n1 * n2
            else:
                print("errore")
print(risultato)
# Out:
# cosa vuoi fare?
# addizione
# dammi il primo numero
# 45
# dammi il secondo numero
# 30
# 75.0

# %% [markdown]
# ![calcolatrice%20completa%20-%20Flowgorithm%2014_11_2023%2009_24_56.png](attachment:calcolatrice%20completa%20-%20Flowgorithm%2014_11_2023%2009_24_56.png)

# %%
print("dammi x y e z")
x = float(input())
y = float(input())
z = float(input())
print("calcolo il quadrato")
quadrato = (x + y + z) ** 2
print(quadrato)
# Out:
# dammi x y e z
# 3
# 5
# 7
# calcolo il quadrato
# 225.0

# %% [markdown]
# ![calcolatore%20secondi%20-%20Flowgorithm%2014_11_2023%2009_30_32.png](attachment:calcolatore%20secondi%20-%20Flowgorithm%2014_11_2023%2009_30_32.png)

# %%
print("dammi l'ora attuale")
h = int(input())
print("dammi i minuti")
m = int(input())
print("dammi i secondi")
s = int(input())
print("calcolo")
seconditot = h * 3600 + m * 60 + s
print("dalla mezzanotte sono passati...")
print(seconditot)
# Out:
# dammi l'ora attuale
# 13
# dammi i minuti
# 35
# dammi i secondi
# 22
# calcolo
# dalla mezzanotte sono passati...
# 48922

# %% [markdown]
# ![areatrapezio%20_%20-%20Flowgorithm%2014_11_2023%2009_37_35.png](attachment:areatrapezio%20_%20-%20Flowgorithm%2014_11_2023%2009_37_35.png)

# %%
print("dammi solo la base minore")
basemin = float(input())
basemag = 3 * basemin
print("calcolo altezza")
altezza = basemag + basemin
print(altezza)
print("calcolo l'area")
area = (basemag + basemin) * altezza / 2
print(area)
# Out:
# dammi solo la base minore
# 5
# calcolo altezza
# 20.0
# calcolo l'area
# 200.0

# %% [markdown]
# ![areatrapezio%20_%20-%20Flowgorithm%2014_11_2023%2009_39_33.png](attachment:areatrapezio%20_%20-%20Flowgorithm%2014_11_2023%2009_39_33.png)

# %%
print("dammi il numero di cui vuoi il fattoriale")
n = int(input())
fatt = 1
for i in range(1, n + 1, 1):
    fatt = fatt * i
print(fatt)
# Out:
# dammi il numero di cui vuoi il fattoriale
# 10
# 3628800

# %% [markdown]
# ![areatrapezio%20_%20-%20Flowgorithm%2014_11_2023%2009_42_04.png](attachment:areatrapezio%20_%20-%20Flowgorithm%2014_11_2023%2009_42_04.png)

# %%
print("dammi i numeri")
n1 = float(input())
n2 = float(input())
if n1 == n2 ** 2:
    print(n1)
    print("è il quadrato del n2")
else:
    if n2 == n1 ** 2:
        print(n2)
        print("è il quadrato del n1")
    else:
        print("sbagliato")
# Out:
# dammi i numeri
# 4
# 2
# 4.0
# è il quadrato del n2

# %% [markdown]
# ![%28Senza%20titolo%29%20_%20-%20Flowgorithm%2020_11_2023%2008_10_27.png](attachment:%28Senza%20titolo%29%20_%20-%20Flowgorithm%2020_11_2023%2008_10_27.png)

# %%
print("insersci popolazione")
pop = int(input())
print("inserisci anni")
anni = int(input())
print("inserisci tasso natalità")
nat = float(input())
print("inserisci tasso mortalità")
mor = float(input())
for anno in range(0, anni + 1, 1):
    n = pop * nat / 100
    m = pop * mor / 100
    pop = pop + n - m
    print("anno")
    print(anno + 1)
    print("popolazione")
    print(pop)
# Out:
# insersci popolazione
# 100
# inserisci anni
# 10
# inserisci tasso natalità
# 2.3
# inserisci tasso mortalità
# 1.2
# anno
# 1
# popolazione
# 101.1
# anno
# 2
# popolazione
# 102.21209999999999
# anno
# 3
# popolazione
# 103.3364331
# anno
# 4
# popolazione
# 104.47313386409999
# anno
# 5
# popolazione
# 105.6223383366051
# anno
# 6
# popolazione
# 106.78418405830774
# anno
# 7
# popolazione
# 107.95881008294913
# anno
# 8
# popolazione
# 109.14635699386156
# anno
# 9
# popolazione
# 110.34696692079405
# anno
# 10
# popolazione
# 111.56078355692279
# anno
# 11
# popolazione
# 112.78795217604893

# %% [markdown]
# ![%28Senza%20titolo%29%20_%20-%20Flowgorithm%2023_11_2023%2008_47_08.png](attachment:%28Senza%20titolo%29%20_%20-%20Flowgorithm%2023_11_2023%2008_47_08.png)

# %%
 n = int(input("Inserisci un numero n per calcolare l'n-esimo numero di Fibonacci: "))

a = 0
b = 1
c = a+b 
if n <= 0:
    print("Il numero deve essere maggiore di 0.")
elif n == 1:
    r = a
else:
    for iterazione in range(n - 3):
        
        a = b
        b = c
        c = a + b
    r = c

print("L'n-esimo numero di Fibonacci è ")
print (r)
# Out:
# Inserisci un numero n per calcolare l'n-esimo numero di Fibonacci: 10
# L'n-esimo numero di Fibonacci è
# 34

# %% [markdown]
# ![flowgorithm%20_%20-%20Flowgorithm%2023_11_2023%2009_16_18.png](attachment:flowgorithm%20_%20-%20Flowgorithm%2023_11_2023%2009_16_18.png)

# %%
print("Benvenuti nel programma di conversione di unità di misura!")
scelta = input("Cosa unità tradurre").lower()


if scelta == "metri": 
    
    valore = float(input("Inserisci il valore in metri: "))
    
    risultato = valore * 3.28084
    print(f"{valore} metri corrispondono a {risultato} piedi.")

elif scelta == "piedi":
    
    valore = float(input("Inserisci il valore in piedi: "))
    
    risultato = valore * 0.3048
    print(f"{valore} piedi corrispondono a {risultato} metri.")

elif scelta == "chilogrammi":
    
    valore = float(input("Inserisci il valore in chilogrammi: "))
    
    risultato = valore * 2.20462
    print(f"{valore} chilogrammi corrispondono a {risultato} libbre.")

elif scelta == "libbre":
    
    valore = float(input("Inserisci il valore in libbre: "))
    
    risultato = valore * 0.453592
    print(f"{valore} libbre corrispondono a {risultato} chilogrammi.")

else:
    
    print("Scelta non valida")
# Out:
# Benvenuti nel programma di conversione di unità di misura!
# Cosa unità tradurremetri
# Inserisci il valore in metri: 34
# 34.0 metri corrispondono a 111.54856 piedi.
